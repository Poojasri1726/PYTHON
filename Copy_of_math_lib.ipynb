# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojasri1726/PYTHON/blob/main/Copy_of_math_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA VISUALIZATION
#
#
#
# 1.Data visualization is the practise of displaying data in visual formats like graphs,maps,charts.
#
#
#
# 2.It helps people undrestand complex information quickly.
#
#
# 3.They turning numbers and data into pictures.

# %%
# !pip install matplotlib
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ASTRICH GRAPH

# %%
Xp=np.array([18,9,13,11,24])
Yp=np.array([17,21,10,12,25])

# %%
plt.plot(Xp, Yp,"*")    #dot-plot
plt.show()

# %% [markdown]
# LINE GRAPH

# %%
p=np.array([15,3,16,14,21])
Yp=np.array([11,22,11,18,25])

# %%
plt.plot(Xp, Yp)  #line-plot
plt.show()

# %% [markdown]
# LINE PLOT WITH MARKERB GRAPH

# %%
p=np.array([12,18,6,19,24])
Yp=np.array([11,22,11,18,23])

# %%
#line-plot with a marker
plt.plot(Xp, Yp,marker="^")
plt.show()
